# %%
# import dependency
import numpy as np

np.random.seed(1)

import os, sys
m_path = os.path.abspath(os.path.join("..\.."))
if m_path not in sys.path:
    sys.path.append(m_path)

# %% [markdown]
# # Process Peelmaps

# %%
from xcloth.train.preprocessing import process_model

data = process_model("../no_git_test_data/88-1/model_cleaned.obj")

# %%
from xcloth.utils import plot_peelmaps

plot_peelmaps(data.peelmap_depth, data.peelmap_rgb, data.peelmap_norm)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from matplotlib import pyplot as plt

plt.imshow(data.img, origin="lower")

# %% [markdown]
# # DataLoader

# %%
from xcloth.train.data import DataLoader

loader = DataLoader()
loader.load("C:/Users/User/CODE/FYP/models/data/deepfashion3d/registered_data")

# %%
from xcloth.utils import plot_peelmaps

data = loader["11-1"]
plot_peelmaps(data.peelmap_depth, data.peelmap_rgb, data.peelmap_norm)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from xcloth.train.preprocessing import process_poses

smpl_depth = process_poses("../no_git_test_data/88-1/88-1.pkl")
# Out:
# c:\Users\User\.conda\envs\fyp-xcloth\lib\site-packages\smplpytorch\pytorch\smpl_layer.py:41: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_numpy.cpp:212.)
#   torch.Tensor(smpl_data['betas'].r).unsqueeze(0))

# %%
from xcloth.utils import plot_depth

plot_depth(smpl_depth)

# %%
def A():
    pass

locals()["A"]
# Out:
# <function __main__.A()>
